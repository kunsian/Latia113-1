# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.image as img
import os
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
x = np.linspace(0, 10, 100)          # 產生 0～10 總共 100 連續數字
y = 4 + 2 * np.sin(2 * x)         # 使用 NumPy 的廣播方式，產生sin 數值的陣列y
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)          # 繪製折線圖
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),  # 設定座標軸
ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()                    # 顯示圖表

# %%
image = img.imread('aa.jpg')
plt.figure(figsize=(5,5))    # 改變圖表尺寸
plt.imshow(image)
plt.show()

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')   # 設定為 3D 圖表
x = range(5)
y = [1,5,8,4,6]
ax.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
# 畫出顏色紅色、圓形錨點、虛線、粗細2、資料點大小6 的線條
plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
#plt.plot(x)
plt.show()

# %%
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.230837  0.980197 -1.011001 -0.366867
# 2013-01-02 -0.779412  1.711429  0.137931  1.266460
# 2013-01-03  2.549709 -1.405810 -1.750340 -1.569566
# 2013-01-04 -1.745260  0.364378  1.334049  0.342700
# 2013-01-05 -1.168611 -1.863526  0.918849 -0.366843
# ...              ...       ...       ...       ...
# 2013-04-06 -1.915509 -2.537076  0.242281 -1.027640
# 2013-04-07 -0.499363 -0.296340 -0.635961  1.768488
# 2013-04-08  2.075477 -1.678221  0.022984 -2.131624
# 2013-04-09 -0.788209  0.052136 -1.525382  0.941038
# 2013-04-10  0.030317 -1.362355 -1.045871  0.012928
#
# [100 rows x 4 columns]

# %% [markdown]
# HW1 畫出ABCD個別的折線圖

# %%
x = df['A']
# 畫出顏色紅色、圓形錨點、虛線、粗細2、資料點大小6 的線條
plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
plt.show()

# %%
x = df['B']
plt.plot(x,color='g', marker='o', linewidth=2, markersize=6)
plt.show()

# %%
x = df['C']
plt.plot(x,color='b', marker='o', linewidth=2, markersize=6)
plt.show()

# %%
x = df['D']
plt.plot(x,color='m', marker='o', linewidth=2, markersize=6)
plt.show()

# %%
x = [1,2,3,4,5]
h = [10,20,30,40,50]
color = ['r','b','g','y','m'] # 顏色數據
label = ['a','b','c','d','e'] # 標籤數據
plt.bar(x,h,color=color,tick_label=label,width=0.5) # 加入顏色、標籤和寬度參數
plt.show()

# %%
x = [1,2,3,4,5]
plt.pie(x, radius=1.5, labels=x)
plt.show()

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')
x = [2,4,6,8,10]
y = 10
z = 1
ax.bar3d(x,y,z,dx=1,dy=1,dz=[1,2,3,4,5])
plt.show()

# %% [markdown]
# 把資料改成pandas產生的資料, 畫出長條圖,圓餅圖, 3D 柱狀長條圖

# %%
plt.bar(dates,df['A'],color='r',tick_label=dates,width=0.5)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.bar(dates,df['B'],color='g',tick_label=dates,width=0.5)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.bar(dates,df['C'],color='b',tick_label=dates,width=0.5)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.bar(dates,df['D'],color='m',tick_label=dates,width=0.5)
# Out:
# <BarContainer object of 100 artists>

# %%
x = [1,2,3,4,5]
plt.pie(abs(df['A']), radius=1.5, labels=dates)
plt.show()

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')
y=10
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=df['A'])
y=12
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=df['B'])
y=14
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=df['C'])
y=16
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=df['D'])
plt.show()

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')
y=10
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=abs(df['A']))
y=12
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=abs(df['B']))
y=14
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=abs(df['C']))
y=16
ax.bar3d(range(100),y,z,dx=1,dy=1,dz=abs(df['D']))
plt.show()

# %%
# %matplotlib inline
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'
# Generate a correlation matrix for the selected columns
corrMatrix = df.corr()
# Plot the correlation matrix using a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
from scipy import stats
# 三個班學生的成績
group1 = [85, 86, 88, 75, 78, 94]
group2 = [92, 94, 89, 96, 93, 95, 76, 50]
group3 = [78, 81, 79, 84, 77, 80]
# 使用scipy.stats.f_oneway 進行單因子 ANOVA 檢定
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
# 輸出結果
print("F 統計量:", f_statistic)
print("p-value:", p_value)
# 解釋結果
alpha = 0.05  # 顯著性水平
if p_value < alpha:
 print("拒絕原假設：不同組別之間的均值存在顯著差異。")
else:
 print("未能拒絕原假設：不同組別之間的均值沒有顯著差異。")
# Out:
# F 統計量: 0.5135486690669941
# p-value: 0.6073604385431465
# 未能拒絕原假設：不同組別之間的均值沒有顯著差異。

# %%
# 創建數據集
data = {
 'Score': [85, 86, 88, 75, 78, 94, 92, 94, 89, 96, 93, 95, 78, 81, 79, 84, 77, 80],
 'Method': ['A', 'A', 'A', 'A', 'A', 'A',  # 教學方法 A
 'B', 'B', 'B', 'B', 'B', 'B',  # 教學方法 B
 'C', 'C', 'C', 'C', 'C', 'C']  # 教學方法 C
}
# 將數據轉換為DataFrame
df = pd.DataFrame(data)
# 使用statsmodels 中的ols 方法進行單因子ANOVA 分析
model = ols('Score ~ C(Method)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
# 輸出ANOVA 表
print(anova_table)
# Out:
#                sum_sq    df          F    PR(>F)
# C(Method)  552.111111   2.0  13.848941  0.000391
# Residual   299.000000  15.0        NaN       NaN

# %%
data2={'score':np.random.randint(0, 101, size=100),'method':np.random.choice(['A','B','C'],100)}
df2=pd.DataFrame(data2)
# 使用statsmodels 中的ols 方法進行單因子ANOVA 分析
model = ols('score ~ C(method)', data=df2).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
# 輸出ANOVA 表
print(anova_table)
# Out:
#                  sum_sq    df         F    PR(>F)
# C(method)    346.292675   2.0  0.235731  0.790445
# Residual   71247.417325  97.0       NaN       NaN

# %%
plt.bar(range(100),df2['score'],color='m',tick_label=df2['method'],width=0.5)
plt.show()
