# %% [markdown]
# 複習之前的

# %%
  import pandas as pd
  import numpy as np

# %%
  df = pd.read_csv('A_stat_data_112.csv')

# %%
  df2 = df.copy()
  df2.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
# 3          非連續                    112            112-2
# 4        連續＋圖表                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3  Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4  Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                     0                             NaN
# 1                 NaN                     0                             NaN
# 2                 NaN                     0                             NaN
# 3                 NaN                     0                             NaN
# 4                 NaN                     0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
# 3                 NaN -6.293485e+18  2.406214e+17
# 4                 NaN  4.998280e+18 -3.340858e+18
#
# [5 rows x 22 columns]

# %% [markdown]
# 實作練習

# %%
  df.head()
  df.tail(3)
  df.index
  df.columns
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %% [markdown]
# 從我的電腦導出數據

# %%
a = df2.columns
a_series = a.to_series()
print(a_series)
a_series.to_csv("work1.csv", index=False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# answer_duration_sec                                      answer_duration_sec
# mission_answer_count                                    mission_answer_count
# content_indicator_correct_rate                content_indicator_correct_rate
# comprehensive_indicator_correct_rate    comprehensive_indicator_correct_rate
# explanation_indicator_correct_rate        explanation_indicator_correct_rate
# extraction_indicator_correct_rate          extraction_indicator_correct_rate
# form_indicator_correct_rate                      form_indicator_correct_rate
# first_correct_rate                                        first_correct_rate
# user_id                                                              user_id
# mission_id                                                        mission_id
# dtype: object

# %% [markdown]
# 分析資料的型態

# %%
df.describe()
# Out:
#                grade  mission_semester_year   is_completed  correct_rate  \
# count  102031.000000               102031.0  102031.000000  24773.000000
# mean        5.624114                  112.0       0.242799      0.404595
# std         1.468450                    0.0       0.428777      0.316659
# min         4.000000                  112.0       0.000000      0.000000
# 25%         4.000000                  112.0       0.000000      0.200000
# 50%         5.000000                  112.0       0.000000      0.400000
# 75%         6.000000                  112.0       0.000000      0.600000
# max         9.000000                  112.0       1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count         24709.000000         102031.000000
# mean            150.183091              0.749164
# std             346.826491              1.760972
# min               1.000000              0.000000
# 25%              10.000000              0.000000
# 50%              35.000000              0.000000
# 75%             174.000000              1.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                     5630.000000                          24486.000000
# mean                         0.371936                              0.407835
# std                          0.473806                              0.399406
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.750000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                        21441.000000                       22464.000000
# mean                             0.376314                           0.430004
# std                              0.445307                           0.453250
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                  4256.000000        25876.000000  1.020300e+05
# mean                      0.365836            0.447990 -4.936111e+16
# std                       0.479152            0.315943  5.362645e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.690198e+18
# 50%                       0.000000            0.400000  6.910637e+16
# 75%                       1.000000            0.600000  4.516202e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.020300e+05
# mean  -7.278681e+16
# std    5.281530e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.265075e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %% [markdown]
# 用excel格式導出數據

# %%
b = df2.describe()
print(b)
b.to_excel("work2.xlsx")
# Out:
#                grade  mission_semester_year   is_completed  correct_rate  \
# count  102031.000000               102031.0  102031.000000  24773.000000
# mean        5.624114                  112.0       0.242799      0.404595
# std         1.468450                    0.0       0.428777      0.316659
# min         4.000000                  112.0       0.000000      0.000000
# 25%         4.000000                  112.0       0.000000      0.200000
# 50%         5.000000                  112.0       0.000000      0.400000
# 75%         6.000000                  112.0       0.000000      0.600000
# max         9.000000                  112.0       1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count         24709.000000         102031.000000
# mean            150.183091              0.749164
# std             346.826491              1.760972
# min               1.000000              0.000000
# 25%              10.000000              0.000000
# 50%              35.000000              0.000000
# 75%             174.000000              1.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                     5630.000000                          24486.000000
# mean                         0.371936                              0.407835
# std                          0.473806                              0.399406
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.750000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                        21441.000000                       22464.000000
# mean                             0.376314                           0.430004
# std                              0.445307                           0.453250
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                  4256.000000        25876.000000  1.020300e+05
# mean                      0.365836            0.447990 -4.936111e+16
# std                       0.479152            0.315943  5.362645e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.690198e+18
# 50%                       0.000000            0.400000  6.910637e+16
# 75%                       1.000000            0.600000  4.516202e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.020300e+05
# mean  -7.278681e+16
# std    5.281530e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.265075e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %% [markdown]
# data sort
# df.sort_index(axis=1, ascending=False)
# axix 0:排序欄
# axis 1:排序列
# ascending = True:升序排列
# ascending = False:降序排列

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#              user_id mission_type mission_status  mission_semester_year  \
# 0      -8.373966e+18           連續          已派發任務                    112
# 1       3.516684e+18           連續          已派發任務                    112
# 2      -6.579905e+16           連續          已派發任務                    112
# 3      -6.293485e+18          非連續          已派發任務                    112
# 4       4.998280e+18        連續＋圖表          已派發任務                    112
# ...              ...          ...            ...                    ...
# 102026  3.396981e+18           連續           完成任務                    112
# 102027 -4.776806e+18           連續           完成任務                    112
# 102028  8.126674e+18           連續           完成任務                    112
# 102029 -4.965955e+18           連續           完成任務                    112
# 102030           NaN           連續           完成任務                    112
#
#        mission_semester                      mission_name    mission_id  \
# 0                 112-2        05/06 虎姑婆【多元文化教育－傳說故事】（初階）  8.154604e+18
# 1                 112-2         05/06 二郎【多元文化教育－傳說故事】（初階）  3.762301e+18
# 2                 112-2         05/09 蚩尤【多元文化教育－傳說故事】（初階）  4.652808e+18
# 3                 112-2        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）  2.406214e+17
# 4                 112-2  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階） -3.340858e+18
# ...                 ...                               ...           ...
# 102026            112-1         10/12 尾牙【多元文化教育－臺灣文化】（初階）  8.381199e+18
# 102027            112-1         10/12 尾牙【多元文化教育－臺灣文化】（初階）  8.381199e+18
# 102028            112-1         10/12 尾牙【多元文化教育－臺灣文化】（初階）  8.381199e+18
# 102029            112-1      10/12 東番記節錄【多元文化教育－臺灣文化】（初階）  2.833450e+18
# 102030            112-1         10/12 尾牙【多元文化教育－臺灣文化】（初階）           NaN
#
#        mission_field mission_difficulty         mission_datetime_utc8  ...  \
# 0                 文學                  易  Mon May 06 08:00:00 UTC 2024  ...
# 1                 文學                  中  Mon May 06 08:00:00 UTC 2024  ...
# 2                 人物                  難  Thu May 09 08:00:00 UTC 2024  ...
# 3               生活知識                  中  Mon May 13 08:00:00 UTC 2024  ...
# 4               自然科學                  易  Thu May 16 08:00:00 UTC 2024  ...
# ...              ...                ...                           ...  ...
# 102026            文化                  中  Thu Oct 12 08:00:00 UTC 2023  ...
# 102027            文化                  中  Thu Oct 12 08:00:00 UTC 2023  ...
# 102028            文化                  中  Thu Oct 12 08:00:00 UTC 2023  ...
# 102029            文學                  難  Thu Oct 12 08:00:00 UTC 2023  ...
# 102030            文化                  中  Thu Oct 12 08:00:00 UTC 2023  ...
#
#         grade  form_indicator_correct_rate  first_correct_rate  \
# 0           5                          NaN                 NaN
# 1           5                          NaN                 NaN
# 2           6                          NaN                 NaN
# 3           5                          NaN                 NaN
# 4           6                          NaN                 NaN
# ...       ...                          ...                 ...
# 102026      5                          NaN                 0.4
# 102027      5                          NaN                 0.0
# 102028      6                          NaN                 0.8
# 102029      5                          NaN                 0.2
# 102030      5                          NaN                 NaN
#
#         extraction_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 102026                                1.0                                 NaN
# 102027                                0.0                                 NaN
# 102028                                1.0                                 NaN
# 102029                                0.0                                 0.0
# 102030                                0.0                                 NaN
#
#         correct_rate  content_indicator_correct_rate  \
# 0                NaN                             NaN
# 1                NaN                             NaN
# 2                NaN                             NaN
# 3                NaN                             NaN
# 4                NaN                             NaN
# ...              ...                             ...
# 102026           0.4                             0.0
# 102027           0.0                             0.0
# 102028           0.8                             0.0
# 102029           0.2                             1.0
# 102030           0.2                             0.0
#
#         comprehensive_indicator_correct_rate             completed_at_utc8  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 102026                                   0.0  Fri Oct 13 10:24:52 UTC 2023
# 102027                                   0.0  Sun Oct 15 23:07:48 UTC 2023
# 102028                                   1.0  Sun Oct 15 14:13:53 UTC 2023
# 102029                                   0.0  Fri Oct 13 08:59:12 UTC 2023
# 102030                                   0.5  Fri Oct 13 09:03:48 UTC 2023
#
#         answer_duration_sec
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 102026                211.0
# 102027                909.0
# 102028                160.0
# 102029                 13.0
# 102030                 17.0
#
# [102031 rows x 22 columns]

# %% [markdown]
# 從一列中提取項目

# %%
 print(df2["user_id"])
 print(df2[0:3])
 df2["user_id"][0:3]
# Out:
# 0        -8.373966e+18
# 1         3.516684e+18
# 2        -6.579905e+16
# 3        -6.293485e+18
# 4         4.998280e+18
#               ...
# 102026    3.396981e+18
# 102027   -4.776806e+18
# 102028    8.126674e+18
# 102029   -4.965955e+18
# 102030             NaN
# Name: user_id, Length: 102031, dtype: float64
#    grade                mission_name mission_difficulty mission_field  \
# 0      5  05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5   05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6   05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                     0                             NaN
# 1                 NaN                     0                             NaN
# 2                 NaN                     0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
#
# [3 rows x 22 columns]
# 0   -8.373966e+18
# 1    3.516684e+18
# 2   -6.579905e+16
# Name: user_id, dtype: float64

# %%
1.
#查詢重複值的個數
a = 'grade'
df2.duplicated(subset=[a]).sum()
# Out:
# 102025

# %%
duplication = df2[df2.duplicated(a)]
duplication[a]
# Out:
# 1         5
# 3         5
# 4         6
# 5         6
# 6         5
#          ..
# 102026    5
# 102027    5
# 102028    6
# 102029    5
# 102030    5
# Name: grade, Length: 102025, dtype: int64

# %%
a = 'user_id'
df3 = df2.drop_duplicates(a)
df3
# Out:
#         grade                      mission_name mission_difficulty  \
# 0           5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1           5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2           6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3           5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4           6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...       ...                               ...                ...
# 101931      4    09/28 如有雷同，純屬巧合【法治教育－法律常識】（初階）                  中
# 101936      4      10/02 網路安全小妙招【法治教育－法律常識】（初階）                  易
# 101953      6      10/02 不知不覺的犯罪【法治教育－法律常識】（初階）                  難
# 102011      6     10/09 腳踏車該騎哪裡？【安全教育－交通安全】（初階）                  中
# 102030      5         10/12 尾牙【多元文化教育－臺灣文化】（初階）                  中
#
#        mission_field mission_type  mission_semester_year mission_semester  \
# 0                 文學           連續                    112            112-2
# 1                 文學           連續                    112            112-2
# 2                 人物           連續                    112            112-2
# 3               生活知識          非連續                    112            112-2
# 4               自然科學        連續＋圖表                    112            112-2
# ...              ...          ...                    ...              ...
# 101931            議題           連續                    112            112-1
# 101936          生活知識           連續                    112            112-1
# 101953            議題           連續                    112            112-1
# 102011            議題          非連續                    112            112-1
# 102030            文化           連續                    112            112-1
#
#                mission_datetime_utc8 mission_status  is_completed  ...  \
# 0       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1       Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2       Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3       Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4       Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                              ...            ...           ...  ...
# 101931  Thu Sep 28 08:00:00 UTC 2023           完成任務             1  ...
# 101936  Mon Oct 02 08:00:00 UTC 2023          已派發任務             0  ...
# 101953  Mon Oct 02 08:00:00 UTC 2023           完成任務             1  ...
# 102011  Mon Oct 09 08:00:00 UTC 2023           完成任務             1  ...
# 102030  Thu Oct 12 08:00:00 UTC 2023           完成任務             1  ...
#
#        answer_duration_sec  mission_answer_count  \
# 0                      NaN                     0
# 1                      NaN                     0
# 2                      NaN                     0
# 3                      NaN                     0
# 4                      NaN                     0
# ...                    ...                   ...
# 101931                86.0                     6
# 101936                 NaN                     0
# 101953               458.0                     2
# 102011                30.0                     4
# 102030                17.0                     2
#
#         content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# ...                                ...                                   ...
# 101931                             NaN                              0.666667
# 101936                             NaN                                   NaN
# 101953                             NaN                              0.500000
# 102011                             NaN                              0.500000
# 102030                             0.0                              0.500000
#
#         explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 101931                                 0.0                                0.0
# 101936                                 NaN                                NaN
# 101953                                 0.0                                0.0
# 102011                                 0.5                                1.0
# 102030                                 NaN                                0.0
#
#         form_indicator_correct_rate  first_correct_rate       user_id  \
# 0                               NaN                 NaN -8.373966e+18
# 1                               NaN                 NaN  3.516684e+18
# 2                               NaN                 NaN -6.579905e+16
# 3                               NaN                 NaN -6.293485e+18
# 4                               NaN                 NaN  4.998280e+18
# ...                             ...                 ...           ...
# 101931                          NaN                 0.4 -1.592331e+18
# 101936                          NaN                 NaN  4.531588e+18
# 101953                          NaN                 0.2  1.284833e+18
# 102011                          NaN                 0.6  7.057736e+18
# 102030                          NaN                 NaN           NaN
#
#           mission_id
# 0       8.154604e+18
# 1       3.762301e+18
# 2       4.652808e+18
# 3       2.406214e+17
# 4      -3.340858e+18
# ...              ...
# 101931  3.217544e+18
# 101936 -3.498194e+18
# 101953  1.792676e+18
# 102011 -8.042941e+17
# 102030           NaN
#
# [8080 rows x 22 columns]

# %%
  p = "one two one two one two".split()
  p1 = 'a1 a2 a3 a4 a5 a6'.split()
  df = pd.DataFrame(
      {
          "A": p,
          "B": p1,
          "C": np.random.randn(6),
          "D": np.random.randn(6)
      }
  )


  df
# Out:
#      A   B         C         D
# 0  one  a1  0.418707  1.397396
# 1  two  a2 -0.086903  0.739741
# 2  one  a3  0.391849  1.717805
# 3  two  a4  0.601134  0.497459
# 4  one  a5 -1.009227  2.124927
# 5  two  a6 -1.524644  0.128879

# %% [markdown]
# 重複資料
# 1.查詢重複數值的個數

# %%
  df.groupby("A").sum()
# Out:
#           B         C         D
# A
# one  a1a3a5 -0.198670  5.240127
# two  a2a4a6 -1.010413  1.366079

# %%
  df.groupby(["A","B"]).sum()
# Out:
#                C         D
# A   B
# one a1  0.418707  1.397396
#     a3  0.391849  1.717805
#     a5 -1.009227  2.124927
# two a2 -0.086903  0.739741
#     a4  0.601134  0.497459
#     a6 -1.524644  0.128879

# %%
df2.groupby("A").sum()
# Out:
#           B         C         D
# A
# one  a1a3a5  0.599421  1.985246
# two  a2a4a6 -1.880815  2.032181

# %%
df2.groupby(["A","B"]).sum()
# Out:
#                C         D
# A   B
# one a1  0.839817  0.344108
#     a3  0.928064  1.224591
#     a5 -1.168460  0.416547
# two a2 -1.148437  1.012111
#     a4 -0.655729 -0.001038
#     a6 -0.076648  1.021109

# %%
#group data
stack = df.stack()
stack
# Out:
# 0  A         one
#    B          a1
#    C    0.839817
#    D    0.344108
# 1  A         two
#    B          a2
#    C   -1.148437
#    D    1.012111
# 2  A         one
#    B          a3
#    C    0.928064
#    D    1.224591
# 3  A         two
#    B          a4
#    C   -0.655729
#    D   -0.001038
# 4  A         one
#    B          a5
#    C    -1.16846
#    D    0.416547
# 5  A         two
#    B          a6
#    C   -0.076648
#    D    1.021109
# dtype: object

# %%
a = df2.columns
pp2 = []
for j in a:
try:
print(df2[j].groupby(df2[j]).count())
pp2.append(df2[j].groupby(df2[j]).count())
except:
print("KeyError")
# Out:
#   File "<ipython-input-24-815809cf9271>", line 4
#     try:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
#輸出 次數分配表到筆記本
with open('次數table_3.txt', 'w', encoding = 'utf-8') as f:
f.write(str(pp2))
f.close
# Out:
#   File "<ipython-input-55-06487c1a4f23>", line 3
#     f.write(str(pp2))
#     ^
# IndentationError: expected an indented block after 'with' statement on line 2

# %%
1.
df1.dropna( )
2.
df1.fillna(5)
3.
df1.interpolate( )
#interpolate’s parameter: "ffill", "bfill", "pad", "backfill"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a151f42ed0d0> in <cell line: 2>()
#       1 1.
# ----> 2 df1.dropna( )
#       3 2.
#       4 df1.fillna(5)
#       5 3.
#
# NameError: name 'df1' is not defined

# %%
df.head(10000).to_excel('output_partial_data.xlsx', index=False)
print("成功將部分數據保存到 Excel 文件")
# Out:
# 成功將部分數據保存到 Excel 文件

# %%
df2 = df.head(10000)
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds,_=default()
gc = gspread.authorize(creds)
import pandas as pd
gsheets = gc.open_by_url("https://docs.google.com/spreadsheets/d/1pmiVKVe0O4yc1hjYnYoEHpxvfa6h6jRcAPMi09UifAY/edit?usp=sharing")
from gspread_dataframe import set_with_dataframe
#select new sheets
worksheet = gsheets.get_worksheet(0)
#taking your DataFrame into Googlesheets
set_with_dataframe(worksheet,df2)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-25-dc30ec308fb0> in <cell line: 3>()
#       1 df2 = df.head(10000)
#       2 from google.colab import auth
# ----> 3 auth.authenticate_user()
#       4 import gspread
#       5 from google.auth import default
#
# /usr/local/lib/python3.10/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
